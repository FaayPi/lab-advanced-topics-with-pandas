# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd

import numpy as pn

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
admissions = pd.read_csv("C:\\Users\\fee10\\Ironhack\\Labs\\lab-advanced-topics-with-pandas\\data\\Admission_Predict.csv")

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
admissions.columns = [col.strip() for col in admissions.columns]
admissions.columns

# or:
# admissions.columns = admissions.columns.str.rstrip()
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:

admissions[admissions.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Serial No., GRE Score, TOEFL Score, University Rating, SOP, LOR, CGPA, Research, Chance of Admit]
# Index: []

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions = admissions.set_index("Serial No.", drop=False)

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions["GRE Score"].count()
admissions.count()
# Out:
# Serial No.           385
# GRE Score            385
# TOEFL Score          385
# University Rating    385
# SOP                  385
# LOR                  385
# CGPA                 385
# Research             385
# Chance of Admit      385
# dtype: int64

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
# Your code here:

admissions["GRE Score - CGPA"] = admissions["GRE Score"].astype(str) + "-" + admissions["CGPA"].astype(str)
admissions = admissions.set_index("GRE Score - CGPA", drop=True)
admissions.head()
# Out:
#                   Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# GRE Score - CGPA
# 337-9.65                   1        337          118                  4  4.5
# 316-8.0                    2        316          104                  3  3.0
# 322-8.67                   3        322          110                  3  3.5
# 314-8.21                   4        314          103                  2  2.0
# 330-9.34                   5        330          115                  5  4.5
#
#                   LOR  CGPA  Research  Chance of Admit
# GRE Score - CGPA
# 337-9.65          4.5  9.65         1             0.92
# 316-8.0           3.5  8.00         1             0.72
# 322-8.67          2.5  8.67         1             0.80
# 314-8.21          3.0  8.21         0             0.65
# 330-9.34          3.0  9.34         1             0.90

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions.reset_index(inplace=True)
admissions.head()
# Out:
#   GRE Score - CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  \
# 0         337-9.65           1        337          118                  4
# 1          316-8.0           2        316          104                  3
# 2         322-8.67           3        322          110                  3
# 3         314-8.21           4        314          103                  2
# 4         330-9.34           5        330          115                  5
#
#    SOP  LOR  CGPA  Research  Chance of Admit
# 0  4.5  4.5  9.65         1             0.92
# 1  3.0  3.5  8.00         1             0.72
# 2  3.5  2.5  8.67         1             0.80
# 3  2.0  3.0  8.21         0             0.65
# 4  4.5  3.0  9.34         1             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
advanced_func_1 = admissions[admissions["CGPA"]> 9][admissions["Research"]>0]
advanced_func_1.head()
# Out:
# C:\Users\fee10\AppData\Local\Temp\ipykernel_19744\3735034162.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   advanced_func_1 = admissions[admissions["CGPA"]> 9][admissions["Research"]>0]
#    GRE Score - CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  \
# 0          337-9.65           1        337          118                  4
# 4          330-9.34           5        330          115                  5
# 10          328-9.1          11        328          112                  4
# 19          328-9.5          20        328          116                  5
# 20          334-9.7          21        334          119                  5
#
#     SOP  LOR  CGPA  Research  Chance of Admit
# 0   4.5  4.5  9.65         1             0.92
# 4   4.5  3.0  9.34         1             0.90
# 10  4.0  4.5  9.10         1             0.78
# 19  5.0  5.0  9.50         1             0.94
# 20  5.0  4.5  9.70         1             0.95

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
advanced_func_2 = admissions[admissions["CGPA"]>9][admissions["SOP"]<3.5]

print(advanced_func_2["Chance of Admit"].mean())
# Out:
# 0.8019999999999999
# C:\Users\fee10\AppData\Local\Temp\ipykernel_19744\3014020363.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   advanced_func_2 = admissions[admissions["CGPA"]>9][admissions["SOP"]<3.5]

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
  
   # Your code here: see next cell

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions["CGPA_std"] = (admissions["CGPA"] - admissions["CGPA"].mean()) / admissions["CGPA"].std()

admissions["GRE_std"] = (admissions["GRE Score"] - admissions["GRE Score"].mean()) / admissions["GRE Score"].std()

admissions["LOR_std"] = (admissions["LOR"] - admissions["LOR"].mean()) / admissions["LOR"].std()
admissions.head()
# Out:
#   GRE Score - CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  \
# 0         337-9.65           1        337          118                  4
# 1          316-8.0           2        316          104                  3
# 2         322-8.67           3        322          110                  3
# 3         314-8.21           4        314          103                  2
# 4         330-9.34           5        330          115                  5
#
#    SOP  LOR  CGPA  Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0  4.5  4.5  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  3.0  3.5  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  3.5  2.5  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  2.0  3.0  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  4.5  3.0  9.34         1             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
# Run this code:

std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])
decision_choice
# Out:
# ['GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
# ...

# %%
decision_choice = pd.DataFrame(decision_choice, columns=["Random Choice"])
decision_choice.head()
# Out:
#   Random Choice
# 0       GRE_std
# 1      CGPA_std
# 2       LOR_std
# 3       LOR_std
# 4       LOR_std

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:

admissions = pd.concat([admissions, decision_choice],axis=1)
print(admissions.head())
# Out:
#   GRE Score - CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  \
# 0         337-9.65           1        337          118                  4
# 1          316-8.0           2        316          104                  3
# 2         322-8.67           3        322          110                  3
# 3         314-8.21           4        314          103                  2
# 4         330-9.34           5        330          115                  5
#
#    SOP  LOR  CGPA  Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  \
# 0  4.5  4.5  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  3.0  3.5  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  3.5  2.5  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  2.0  3.0  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  4.5  3.0  9.34         1             0.90  1.233279  1.147798 -0.480713
#
#   Random Choice Random Choice
# 0       GRE_std       GRE_std
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:

admissions["decision"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\fee10\Downloads\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'decision'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[194], line 3
#       1 # Your code here:
# ----> 3 admissions["decision"]
# ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
